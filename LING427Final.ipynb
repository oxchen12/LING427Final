# %%
import pandas as pd
import urllib
import re
from dataclasses import dataclass

pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %%
# download the source data
DATA_SOURCE = "https://cdr.lib.unc.edu/downloads/8623j7090?locale=en"
urllib.request.urlretrieve(DATA_SOURCE, "PRONOM2022.csv")
# Out:
# ('PRONOM2022.csv', <http.client.HTTPMessage at 0x7f561fe6a950>)

# %%
raw = pd.read_csv("PRONOM2022.csv")
# filter out rows without dual/trial values
data = raw[raw.loc[:,"1+2(incl), Restricted I (dual/min);": "3 Restricted II (trial/pauc)"].notnull().any(axis=1)]
data = data.sort_values(by="Language")

# %%
# define classes and functions for data analysis
NUMBERS = ("sg", "pl", "dual", "trial")

@dataclass
class Syncretism:
    form: str
    cells: list[str]
    
    def persons(self):
        persons = set()
        for cell in self.cells:
            m = re.match(r"\d(\+\d)?(\+\d)?", cell)
            if m:
                persons.add(m.group(0))
        return persons
    
    def syn_type(self):
        m = g = mg = False
        for cell in self.cells:
            m = m or "sg" in cell
            g = g or "pl" in cell
            mg = mg or ("dual" in cell or "trial" in cell)
        
        if m and g and mg:
            return "other"
        elif m and mg:
            return "minimal"
        elif g and mg:
            return "group"
        
    def numbers(self):
        numbers = set()
        for cell in self.cells:
            for number in NUMBERS:
                if number in cell:
                    numbers.add(number)
        return numbers

class SyncretismSet:
    def __init__(self, language: str):
        self.language: str = language
        self.syncretisms: list[Syncretism] = []

    def __repr__(self):
        return f"SyncretismSet(language='{self.language}', count={len(self.syncretisms)})"

def number_syncretisms(row, person=False):
    forms = {}

    for cell, val in row["1sg":"3 Restricted II (trial/pauc)"].dropna().items():
        if val not in forms:
            forms[val] = []
        forms[val].append(cell)

    syns = []
    for form, cells in forms.items():
        if len(cells) <= 1 or not is_number_syncretism(cells):
            continue
        if not person:
            syns.append(Syncretism(form, cells))
        else:
            # separate form by person values
            if not is_number_syncretism(cells):
                continue
            persons = {}
            for cell in cells:
                p = re.match(r"\d(\+\d)?(\+\d)?", cell).group(0)
                if p is None:
                    continue
                if p not in persons:
                    persons[p] = []
                persons[p].append(cell)
            for person, pcells in persons.items():
                if len(pcells) > 1:
                    syns.append(Syncretism(form, pcells))

    return syns

def is_number_syncretism(cells: list):
    m = g = mg = False
    for cell in cells:
        m = m or "sg" in cell
        g = g or "pl" in cell
        mg = mg or ("dual" in cell or "trial" in cell)
    return mg and (m or g)

# %%
"""Syncretisms by paradigm."""
syn_paradigm_df = data.copy()

def join_multiline(coll):
    out = "\n".join(str(e).strip("{}()").replace("'", "") for e in coll)
    return pd.NA if not out else out

def row_to_num_syncretisms(row, person):
    syns = [(syn.form, tuple(syn.cells)) for syn in number_syncretisms(row, person=person)]
    syns.sort(key=lambda s: s[0])
    return join_multiline(syns)

def row_to_persons(row):
    persons = tuple(syn.persons() for syn in number_syncretisms(row))
    return join_multiline(persons)

def row_to_syn_types(row):
    types = tuple(syn.syn_type() for syn in number_syncretisms(row, person=False))
    return join_multiline(types)

def row_to_numbers(row):
    numbers = tuple(syn.numbers() for syn in number_syncretisms(row, person=False))
    return join_multiline(numbers)

syn_paradigm_df['# Syncretisms'] = syn_paradigm_df.apply(lambda r : len(number_syncretisms(r, person=False)), axis=1)
syn_paradigm_df['Syncretisms'] = syn_paradigm_df.apply(lambda r : row_to_num_syncretisms(r, False), axis=1)
syn_paradigm_df = syn_paradigm_df.dropna(subset=['Syncretisms'])
syn_paradigm_df['Syncretisms (person-separated)'] = syn_paradigm_df.apply(lambda r : row_to_num_syncretisms(r, True), axis=1)
syn_paradigm_df['Persons'] = syn_paradigm_df.apply(row_to_persons, axis=1)
syn_paradigm_df['Numbers'] = syn_paradigm_df.apply(row_to_numbers, axis=1)
syn_paradigm_df['Type'] = syn_paradigm_df.apply(row_to_syn_types, axis=1)

syn_paradigm_df = syn_paradigm_df.sort_values(by="Language")

syn_paradigm_df.to_csv("PRONOM2022_syn-num.csv", index=False, mode='w')
syn_paradigm_df
# Out:
#      Language counter                 Language               Genus  \
# 603               218                    Aleut        Eskimo-Aleut
# 228               218                    Aleut        Eskimo-Aleut
# 619               231           Bininj Gun-Wok          Gunwinygic
# 617               231           Bininj Gun-Wok          Gunwinygic
# 386                17                 Cherokee  Southern Iroquoian
# 387                17                 Cherokee  Southern Iroquoian
# 438                52               Gooniyandi             Bunuban
# 182                52               Gooniyandi             Bunuban
# 335                14                    Haida               Haida
# 366                14                    Haida               Haida
# 188                83                     Hopi                Hopi
# 85                162                     Kewa               Engan
# 41                 77                    Kobon              Madang
# 557               194                   Kunama        Nilo-Saharan
# 272               194                   Kunama        Nilo-Saharan
# 616               224               Mangarrayi          Mangarrayi
# 618               224               Mangarrayi          Mangarrayi
# 622               224               Mangarrayi          Mangarrayi
# 624               224               Mangarrayi          Mangarrayi
# 354               180               Mapudungun          Araucanian
# 416               176               Nambikuára         Nambikuaran
# 521               176               Nambikuára         Nambikuaran
# 295                 4                   Ngandi              Ngandi
# 549               167                  Nisenan             Maiduan
# 139                57  Sierra Miwok (Southern)               Utian
# 493               226                  Tonkawa    Language Isolate
# 383                16                 Worrorra           Worrorran
# 584               213                    Yagua         Peba-Yaguan
# 120               213                    Yagua         Peba-Yaguan
# 207               123                     Zuni                Zuni
# 310               123                     Zuni                Zuni
#
#                        Area Language code  \
# 603           North America           ale
# 228           North America           ale
# 619  Australia & New Guinea           gup
# 617  Australia & New Guinea           gup
# 386           North America           chr
# 387           North America           chr
# 438  Australia & New Guinea           gni
# 182  Australia & New Guinea           gni
# 335           North America      hax, hdn
# 366           North America      hax, hdn
# 188           North America           hop
# 85   Australia & New Guinea           kew
# 41   Australia & New Guinea           kpw
# 557                  Africa           kun
# 272                  Africa           kun
# 616  Australia & New Guinea           mpc
# 618  Australia & New Guinea           mpc
# 622  Australia & New Guinea           mpc
# 624  Australia & New Guinea           mpc
# 354           South America           arn
# 416           South America           nab
# 521           South America           nab
# 295  Australia & New Guinea           nid
# 549           North America           nsz
# 139           North America           skd
# 493           North America           tqw
# 383  Australia & New Guinea           unp
# 584           South America           yad
# 120           South America           yad
# 207           North America           zun
# 310           North America           zun
#
#                                               paradigm       Free/Bound  \
# 603  Free Personal Pronouns (Postpositional, 'for/a...             Free
# 228           Free Personal Pronouns (Nominative Case)             Free
# 619  Verbal Subject and Object Agreement Affixes (T...   Bound (Verbal)
# 617  Verbal Subject and Object Agreement Affixes (T...   Bound (Verbal)
# 386     Verbal Subject Agreement Affixes (Active Mood)   Bound (Verbal)
# 387    Verbal Subject Agreement Affixes (Stative Mood)   Bound (Verbal)
# 438              Free Personal Pronouns (Oblique Case)             Free
# 182           Free Personal Pronouns (Nominative Case)             Free
# 335                           Free Possessive Pronouns             Free
# 366               Free Possessive Pronouns (Reflexive)             Free
# 188           Free Personal Pronouns (Nominative Case)             Free
# 85                              Free Personal Pronouns             Free
# 41                              Free Personal Pronouns             Free
# 557   Verbal Subject Agreement Affixes (Class I Verbs)   Bound (Verbal)
# 272                                 Possessive Affixes  Bound (Nominal)
# 616  Verbal Subject and Object Agreement Affixes (T...   Bound (Verbal)
# 618  Verbal Subject and Object Agreement Affixes (T...   Bound (Verbal)
# 622  Verbal Subject and Object Agreement Affixes (T...   Bound (Verbal)
# 624  Verbal Subject and Object Agreement Affixes (T...   Bound (Verbal)
# 354                           Free Possessive Pronouns             Free
# 416                   Verbal Subject Agreement Affixes   Bound (Verbal)
# 521                    Verbal Object Agreement Affixes   Bound (Verbal)
# 295  Verbal Subject and Object Agreement Affixes (T...   Bound (Verbal)
# 549        Verbal Subject Agreement Affixes (Optative)   Bound (Verbal)
# 139                             Free Personal Pronouns             Free
# 493           Free Personal Pronouns (Accusative Case)             Free
# 383   Verbal Object Agreement Affixes (Objective Case)   Bound (Verbal)
# 584           Verbal Subject Agreement Clitics (Set I)   Bound (Verbal)
# 120                             Free Personal Pronouns             Free
# 207           Free Personal Pronouns (Nominative Case)             Free
# 310               Free Personal Pronouns (Object Case)             Free
#
#                                              1sg  \
# 603                                    agalkimiŋ
# 228                                          θiŋ
# 619                                 (ŋ)abanbani-
# 617                                     (ŋ)aban-
# 386                                     tsi-; k-
# 387                                   aki-; akw-
# 438                                       ŋadagi
# 182                                         ŋaɲi
# 335                                           di
# 366                                 gɪæŋ; kɪægɪn
# 188                                          nɯʔ
# 85                                           ni˦
# 41                                         (j)ad
# 557                                          -na
# 272                                        -aŋ-a
# 616                                     ŋawujan-
# 618                                     nawuɾan-
# 622                                       ɳujan-
# 624                                       ɳuɾan-
# 354                                           ɲi
# 416                                         -a˥˩
# 521                                         -sa˩
# 295                                        ŋana-
# 549                                          -is
# 139  kani (nominative case); kan (genitive case)
# 493                                      ʃ̟aʃ̟ɪk
# 383                                  -ara; -gʌra
# 584                                    raj-; ri-
# 120                                          raj
# 207                                          hoʔ
# 310                                          hom
#
#                                                    2sg  \
# 603                                          agalkimin
# 228                                               txin
# 619                                         jibanbani-
# 617                                             jiban-
# 386                                              h(i)-
# 387                                             ts(a)-
# 438                                             ŋa:ŋgi
# 182                                              ŋiɲɟi
# 335                                               dʌng
# 366                                            dʌŋgɪaw
# 188                                                 ɯm
# 85                                                 ne˨
# 41                                              ne; nɨ
# 557                                                -nu
# 272                                               -e-a
# 616                                           ɲawujan-
# 618                                           ɲawuɾan-
# 622                                                NaN
# 624                                                NaN
# 354                                                 mi
# 416                                              -in˥˩
# 521                                             -ʔna˩˥
# 295                                              ɳuna-
# 549          -bene; -beneka (absent); -benes (present)
# 139  mi (nominative); miːn (genitive); miːni (other...
# 493                                              naʝɐk
# 383                                           -nu; -du
# 584                                          hij-; ji-
# 120                                                hij
# 207                                                toʔ
# 310                                                tom
#
#                                                  3sg  \
# 603                                          agalˈan
# 228                                            hiŋan
# 619                                     (ga)banbani-
# 617                                         (ga)ban-
# 386                                  ka-; k-; a-; Ø-
# 387                                               u-
# 438                                          nho:wo:
# 182                                             niji
# 335                                               ɪl
# 366                                   lagɪaw (anim.)
# 188                                              NaN
# 85                                            ni˨pu˦
# 41                                          nipe; ne
# 557                                              -su
# 272                                             -i-a
# 616                                           wujan-
# 618                                           wuɾan-
# 622                                           ɳujan-
# 624                                           ɳuɾan-
# 354                                               ɲi
# 416                                               -∅
# 521                                               -∅
# 295                            Ø- (masc.); Ø- (fem.)
# 549                                              -ɓo
# 139                                            ʔisak
# 493                                          ʔɐʝelɐk
# 383  -nʌŋga; -dʌga (masc.); -nʌŋgʌɲa; -dʌgʌɲa (fem.)
# 584                                    sa-; si-; su-
# 120                                              ní:
# 207                                                Ø
# 310                                              ʔan
#
#                   1+2+3pl(incl)         1+3pl(excl)  \
# 603          agalkiŋin; agalkin  agalkiŋin; agalkin
# 228                       tuman               tuman
# 619  garbanbani-; (ŋ)arbanbani-       (ŋ)arbanbani-
# 617          garban-; (ŋ)arban-           (ŋ)arban-
# 386                      it(i)-             ots(i)-
# 387                      ik(i)-              ok(i)-
# 438                     ja:daŋi              ŋidaŋi
# 182                       ja:di                ŋidi
# 335                        itɪl                itɪl
# 366                    itɪlgɪaw            itɪlgɪaw
# 188                        itam                itam
# 85                      ni˦a˦a˦             ni˦a˦a˦
# 41                          hon                 hon
# 557                         -di                 -ma
# 272                      -iŋŋ-a               -áŋ-a
# 616                  ŋaɭawujan-          ŋiɭawujan-
# 618                  ŋaɭawuɾan-          ŋiɭawuɾan-
# 622                         NaN              ɳujan-
# 624                         NaN              ɳuɾan-
# 354                          iɲ                  iɲ
# 416                        -kḭ˩          -sĩn˥˩-a˥˩
# 521                        -ne˩         -sa˩˥-sĩn˥˩
# 295                       ŋana-               ɲana-
# 549                         -pɨ                 -pɨ
# 139                      ʔotiti                mahi
# 493                   gɛuʃ̟agɐk           gɛuʃ̟agɐk
# 383                -ŋæri; -gʌri       -ɲæri; -djʌri
# 584              wũ:j-; wudʲa-      nú:j-; nú:ndʲa
# 120                       wũ:j                nú:j
# 207                         hon                 hon
# 310                      hoʔnaʔ              hoʔnaʔ
#
#                               2pl                3pl  \
# 603                    agalkimtʃi          agalkimaŋ
# 228                        txitʃi             iŋakun
# 619  (g)urbanbani-; (ŋ)urbanbani-         (ga)bandi-
# 617          (ŋ)urban-; (g)urban-         (ga)bandi-
# 386                       its(i)-             an(i)-
# 387                       its(i)-             un(i)-
# 438                        gidaŋi             bidaŋi
# 182                          gidi               bidi
# 335                         dælʌŋ               lthæ
# 366                     dælʌŋgɪaw           lthagɪaw
# 188                           ɯma                NaN
# 85                         ni˨mi˨             ni˨mu˦
# 41                      kəl; kale  kəl; kale; kalɨpe
# 557                           -mu                -mu
# 272                          -é-a               -í-a
# 616                      ɭawujan-           wujanba-
# 618                      ɭawujan-           wujanba-
# 622                           NaN           ɳujanba-
# 624                           NaN           ɳuɾanba-
# 354                           mɨn                 ɲi
# 416                 -yah˩-ʔl-a˥˩-             -ain˥˩
# 521                      ʔn˩˥-ti˩             -ain˥˩
# 295                         ɳana-              bana-
# 549       -ɓa:m; -ɓa:mka (absent)                -ɓo
# 139                          miko          ʔisak-koː
# 493                       wɛnaʝɐk            ʔɐwelɐk
# 383                   -nuri; duri  -nʌŋgori; -dʌgori
# 584               hidʲej-; hidʲa-  rij-; ru-; ridʲa-
# 120                        hidʲéj                rij
# 207                           ton                  Ø
# 310                        toʔnaʔ             ʔa:wan
#
#     1+2(incl), Restricted I (dual/min); 1+3(excl), Restricted I (dual/min)  \
# 603                  agalkiŋin; agalkin                 agalkiŋin; agalkin
# 228                               tuman                              tuman
# 619                       (ŋ)arbanbani-                      (ŋ)arbanbani-
# 617                           (ŋ)arban-                          (ŋ)arban-
# 386                              in(i)-                            ost(i)-
# 387                            ikin(i)-                           okin(i)-
# 438                              ŋidaŋi                             ŋidaŋi
# 182                                ŋidi                               ŋidi
# 335                                 NaN                                NaN
# 366                                 NaN                                NaN
# 188                                itam                               itam
# 85                                sa˦a˦                              sa˦a˦
# 41                                  hol                                hol
# 557                                 -di                                -ma
# 272                              -íŋŋ-a                             -íŋŋ-a
# 616                            ŋiwujan-                          ŋiɾwujan-
# 618                            ŋiwuɾan-                          ŋiɾwuɾan-
# 622                                 NaN                             ɳujan-
# 624                                 NaN                             ɳuɾan-
# 354                                  ju                                 ju
# 416                                -kḭ˩                         -yah˩-a˥˩-
# 521                                -ne˩                            -s-yah˩
# 295                               ɲana-                      ɲana- (masc.)
# 549                                 -pe                                -pe
# 139                             ʔotihme                               mahi
# 493                          gɛuʃ̟aʃ̟ɪk                         gɛuʃ̟aʃ̟ɪk
# 383                  -ŋærendu; -gʌrendu                -ɲærendu; -djʌrendu
# 584                      wũ:j-; wudʲa-                     náj-; ná:ndʲa-
# 120                               wũ:j                               ná:j
# 207                                 hon                                hon
# 310                              hoʔnaʔ                             hoʔnaʔ
#
#         2 Restricted I (dual/min) 3 Restricted I (dual/min)  \
# 603                   agalkimiðik                 agalkimak
# 228                        txiðik                     iŋaku
# 619  (g)urbanbani-; (ŋ)urbanbani-                (ga)bandi-
# 617          (ŋ)urban-; (g)urban-                (ga)bandi-
# 386                        st(i)-                    an(i)-
# 387                        st(i)-                    un(i)-
# 438                           NaN                       NaN
# 182                           NaN                       NaN
# 335                           NaN                        ɪl
# 366                           NaN            lagɪaw (anim.)
# 188                           ɯma                       NaN
# 85                         ni˨pi˨                    ni˨pu˦
# 41                      kəl; kale         kəl; kale; kalɨpe
# 557                           -mu                       -mu
# 272                          -é-a                      -í-a
# 616                      ɭawujan-                  wujanba-
# 618                      ɭawujan-                  wujanba-
# 622                           NaN                 ɳujanbuɾ-
# 624                           NaN                 ɳuɾanbuɾ-
# 354                            mu                        ɲi
# 416                   -yah˩-in˥˩-                     -yah˩
# 521                     -ʔn˩˥-ti˩                     -yah˩
# 295                 ɳana- (masc.)             bana- (masc.)
# 549       -ɓe:m; -ɓe:mka (absent)                       -ɓo
# 139                           NaN                       NaN
# 493                       wɛnaʝɐk                   ʔɐwelɐk
# 383             -nurendu; durendu       -nʌŋgandu; -dʌgandu
# 584           sã́:nda-; sã́:na-                   na:nda-
# 120                      sã́:nda                    na:nda
# 207                           ton                   ʔa:t͡ʃi
# 310                        toʔnaʔ                ʔa:t͡ʃijaʔ
#
#     1+2+3t(incl), Restricted II (trial/pauc)  \
# 603                                      NaN
# 228                                      NaN
# 619               garbanbani-; (ŋ)arbanbani-
# 617                                (ŋ)arban-
# 386                                      NaN
# 387                                      NaN
# 438                                      NaN
# 182                                      NaN
# 335                                      NaN
# 366                                      NaN
# 188                                      NaN
# 85                                       NaN
# 41                                       NaN
# 557                                      NaN
# 272                                      NaN
# 616                                ŋaɾwujan-
# 618                                ŋaɾwuɾan-
# 622                                      NaN
# 624                                      NaN
# 354                                      NaN
# 416                                      NaN
# 521                                      NaN
# 295                            ŋana- (masc.)
# 549                                      NaN
# 139                                      NaN
# 493                                      NaN
# 383                   -ŋæriŋguri; -gʌriŋguri
# 584                                      NaN
# 120                                      NaN
# 207                                      NaN
# 310                                      NaN
#
#     1+3(excl), Restricted II (trial/pauc) 2 Restricted II (trial/pauc)  \
# 603                                   NaN                          NaN
# 228                                   NaN                          NaN
# 619                                   NaN                          NaN
# 617                                   NaN                          NaN
# 386                                   NaN                          NaN
# 387                                   NaN                          NaN
# 438                                   NaN                          NaN
# 182                                   NaN                          NaN
# 335                                   NaN                          NaN
# 366                                   NaN                          NaN
# 188                                   NaN                          NaN
# 85                                    NaN                          NaN
# 41                                    NaN                          NaN
# 557                                   NaN                          NaN
# 272                                   NaN                          NaN
# 616                                   NaN                          NaN
# 618                                   NaN                          NaN
# 622                                   NaN                          NaN
# 624                                   NaN                          NaN
# 354                                   NaN                          NaN
# 416                                   NaN                          NaN
# 521                                   NaN                          NaN
# 295                                   NaN                          NaN
# 549                                   NaN                          NaN
# 139                                   NaN                          NaN
# 493                                   NaN                          NaN
# 383               -ɲæriŋguri; -djʌriŋguri        -nuriŋguri; duriŋguri
# 584                                   NaN                          NaN
# 120                                   NaN                          NaN
# 207                                   NaN                          NaN
# 310                                   NaN                          NaN
#
#     3 Restricted II (trial/pauc) 1st (No number) 1st(incl) (No number)  \
# 603                          NaN             NaN                   NaN
# 228                          NaN             NaN                   NaN
# 619                          NaN             NaN                   NaN
# 617                          NaN             NaN                   NaN
# 386                          NaN             NaN                   NaN
# 387                          NaN             NaN                   NaN
# 438                          NaN             NaN                   NaN
# 182                          NaN             NaN                   NaN
# 335                          NaN             NaN                   NaN
# 366                          NaN             NaN                   NaN
# 188                          NaN             NaN                   NaN
# 85                           NaN             NaN                   NaN
# 41                           NaN             NaN                   NaN
# 557                          NaN             NaN                   NaN
# 272                          NaN             NaN                   NaN
# 616                          NaN             NaN                   NaN
# 618                          NaN             NaN                   NaN
# 622                          NaN             NaN                   NaN
# 624                          NaN             NaN                   NaN
# 354                          NaN             NaN                   NaN
# 416                          NaN             NaN                   NaN
# 521                          NaN             NaN                   NaN
# 295                          NaN             NaN                   NaN
# 549                          NaN             NaN                   NaN
# 139                          NaN             NaN                   NaN
# 493                          NaN             NaN                   NaN
# 383            -nʌŋgori; -dʌgori             NaN                   NaN
# 584                          NaN             NaN                   NaN
# 120                          NaN             NaN                   NaN
# 207                          NaN             NaN                   NaN
# 310                          NaN             NaN                   NaN
#
#     2nd (No number) 3rd (No number)  \
# 603             NaN             NaN
# 228             NaN             NaN
# 619             NaN             NaN
# 617             NaN             NaN
# 386             NaN             NaN
# 387             NaN             NaN
# 438             NaN             NaN
# 182             NaN             NaN
# 335             NaN             NaN
# 366             NaN             NaN
# 188             NaN             NaN
# 85              NaN             NaN
# 41              NaN             NaN
# 557             NaN             NaN
# 272             NaN             NaN
# 616             NaN             NaN
# 618             NaN             NaN
# 622             NaN             NaN
# 624             NaN             NaN
# 354             NaN             NaN
# 416             NaN             NaN
# 521             NaN             NaN
# 295             NaN             NaN
# 549             NaN             NaN
# 139             NaN             NaN
# 493             NaN             NaN
# 383             NaN             NaN
# 584             NaN             NaN
# 120             NaN             NaN
# 207             NaN             NaN
# 310             NaN             NaN
#
#                                                 Other1              Other2  \
# 603                                                NaN                 NaN
# 228                               txiðin; txitʃiŋanˈan          txitʃiŋˈan
# 619                                                NaN                 NaN
# 617                                                NaN                 NaN
# 386                                                NaN                 NaN
# 387                                                NaN                 NaN
# 438                                                NaN                 NaN
# 182                                                NaN                 NaN
# 335                                                NaN                 NaN
# 366                                                NaN                 NaN
# 188                                                NaN                 NaN
# 85                                                 NaN                 NaN
# 41                                                 NaN                 NaN
# 557                                                NaN                 NaN
# 272                                                NaN                 NaN
# 616                                                NaN                 NaN
# 618                                                NaN                 NaN
# 622                                                NaN                 NaN
# 624                                                NaN                 NaN
# 354                                                NaN                 NaN
# 416                                                NaN                 NaN
# 521                                        ya˩-s-ain˥˩  ya˩-s-ain˥˩-sĩn˥˩
# 295  Ø- (ni class); Ø- (na class); ɳaguɽa- (a class...               ɳina-
# 549                                                NaN                 NaN
# 139                                                NaN                 NaN
# 493                                                NaN                 NaN
# 383                                                NaN                 NaN
# 584                                          híj-; jí-            rá-; rí-
# 120                                                NaN                 NaN
# 207                                                NaN                 NaN
# 310                                                NaN                 NaN
#
#                                                  Notes  \
# 603  These postpositional pronouns indicate "for" o...
# 228  Other I includes second person plural emphatic...
# 619  The morpheme -bani indicates third person dual...
# 617  The morpheme -ban indicates third person plura...
# 386  There are two sets of 3rd person markers in th...
# 387                                                NaN
# 438                                                NaN
# 182  Transcription is phonemic. /ŋidi/ is used for ...
# 335                                   I.e., "my", etc.
# 366                               I.e., "my own", etc.
# 188  Plural and dual are conflated in the pronouns....
# 85   Singular/dual can be ambiguous in third person...
# 41   Emphatic forms also exist, but they are morpho...
# 557                                                NaN
# 272                                                NaN
# 616                                                NaN
# 618                                                NaN
# 622                                                NaN
# 624                                                NaN
# 354                                                NaN
# 416  Dual inclusive is not explicitely given (I ass...
# 521  Dual inclusive is not explicitely given (I ass...
# 295  The a class prefix ɳaguɽa- is syncretic with t...
# 549                                                NaN
# 139                                                NaN
# 493                                                NaN
# 383                                                NaN
# 584  Other I shows two allomorphs of the Set I core...
# 120                                                NaN
# 207                                                NaN
# 310  The 3rd person singular and plural forms are o...
#
#                                                 Source  Comments  \
# 603  Geoghegan, Richard Henry. 1944. The Aleut Lang...       NaN
# 228  Geoghegan, Richard Henry. 1944. The Aleut Lang...       NaN
# 619  Evans, Nicholas. 2003. Bininj Gun-Wok: A pan-d...       NaN
# 617  Evans, Nicholas. 2003. Bininj Gun-Wok: A pan-d...       NaN
# 386  King, Duane Harold. 1975. A Grammar and Dictio...       NaN
# 387  King, Duane Harold. 1975. A Grammar and Dictio...       NaN
# 438  McGregor, William. 1990. A Functional Grammar ...       NaN
# 182  McGregor, William. 1990. A Functional Grammar ...       NaN
# 335  Harrison, Charles. 1895. Haida Grammar. Ottawa...       NaN
# 366  Harrison, Charles. 1895. Haida Grammar. Ottawa...       NaN
# 188  University of Arizona. Hopi Dictionary Project...       NaN
# 85   Franklin, Karl James. 1971. A Grammar of Kewa,...       NaN
# 41   Davies, John. 1989. Kobon. London; New York: R...       NaN
# 557  Bender, Lionel M. 1996. Kunama. Munich: LINCOM...       NaN
# 272  Bender, Lionel M. 1996. Kunama. Munich: LINCOM...       NaN
# 616  Merlan, Francesca. 1989. Mangarayi. London: Ro...       NaN
# 618  Merlan, Francesca. 1989. Mangarayi. London: Ro...       NaN
# 622  Merlan, Francesca. 1989. Mangarayi. London: Ro...       NaN
# 624  Merlan, Francesca. 1989. Mangarayi. London: Ro...       NaN
# 354  Zúñiga, Fernando. 2000. Mapudungun. Munich: LI...       NaN
# 416  Kroeker, Menno. 2001. A Descriptive Grammar of...       NaN
# 521  Kroeker, Menno. 2001. A Descriptive Grammar of...       NaN
# 295  Heath, Jeffrey. 1978. Ngandi Grammar, Texts, a...       NaN
# 549  Eatough, Andrew. 1999. Central Hill Nisenan Te...       NaN
# 139  Broadbent, Sylvia M. 1964. The Southern Sierra...       NaN
# 493  Hoijer, Harry. 1931. Tonkawa: An Indian Langua...       NaN
# 383  Clendon, Mark. 2014. Worrora: a language of th...       NaN
# 584  Payne, Doris. L. and Payne, Thomas. E. 1990. Y...       NaN
# 120  Payne, Doris. L. and Payne, Thomas. E. 1990. Y...       NaN
# 207  Newman, Stanley S. 1965. Zuni Grammar. Albuque...       NaN
# 310  Newman, Stanley S. 1965. Zuni Grammar. Albuque...       NaN
#
#      # Syncretisms                                        Syncretisms  \
# 603              1  agalkiŋin; agalkin, (1+2+3pl(incl), 1+3pl(excl...
# 228              1  tuman, (1+2+3pl(incl), 1+3pl(excl), 1+2(incl),...
# 619              4  (g)urbanbani-; (ŋ)urbanbani-, (2pl, 2 Restrict...
# 617              3  (ga)bandi-, (3pl, 3 Restricted I (dual/min)\n(...
# 386              1            an(i)-, (3pl, 3 Restricted I (dual/min)
# 387              1            un(i)-, (3pl, 3 Restricted I (dual/min)
# 438              1  ŋidaŋi, (1+3pl(excl), 1+2(incl), Restricted I ...
# 182              1  ŋidi, (1+3pl(excl), 1+2(incl), Restricted I (d...
# 335              1                ɪl, (3sg, 3 Restricted I (dual/min)
# 366              1    lagɪaw (anim.), (3sg, 3 Restricted I (dual/min)
# 188              2  itam, (1+2+3pl(incl), 1+3pl(excl), 1+2(incl), ...
# 85               1            ni˨pu˦, (3sg, 3 Restricted I (dual/min)
# 41               2  kəl; kale, (2pl, 2 Restricted I (dual/min)\nkə...
# 557              3  -di, (1+2+3pl(incl), 1+2(incl), Restricted I (...
# 272              2  -é-a, (2pl, 2 Restricted I (dual/min)\n-í-a, (...
# 616              2  wujanba-, (3pl, 3 Restricted I (dual/min)\nɭaw...
# 618              2  wujanba-, (3pl, 3 Restricted I (dual/min)\nɭaw...
# 622              1  ɳujan-, (1sg, 3sg, 1+3pl(excl), 1+3(excl), Res...
# 624              1  ɳuɾan-, (1sg, 3sg, 1+3pl(excl), 1+3(excl), Res...
# 354              1      ɲi, (1sg, 3sg, 3pl, 3 Restricted I (dual/min)
# 416              1  -kḭ˩, (1+2+3pl(incl), 1+2(incl), Restricted I ...
# 521              1  -ne˩, (1+2+3pl(incl), 1+2(incl), Restricted I ...
# 295              1  ɲana-, (1+3pl(excl), 1+2(incl), Restricted I (...
# 549              1          -ɓo, (3sg, 3pl, 3 Restricted I (dual/min)
# 139              1  mahi, (1+3pl(excl), 1+3(excl), Restricted I (d...
# 493              2  wɛnaʝɐk, (2pl, 2 Restricted I (dual/min)\nʔɐwe...
# 383              1  -nʌŋgori; -dʌgori, (3pl, 3 Restricted II (tria...
# 584              1  wũ:j-; wudʲa-, (1+2+3pl(incl), 1+2(incl), Res...
# 120              1  wũ:j, (1+2+3pl(incl), 1+2(incl), Restricted I...
# 207              2  hon, (1+2+3pl(incl), 1+3pl(excl), 1+2(incl), R...
# 310              2  hoʔnaʔ, (1+2+3pl(incl), 1+3pl(excl), 1+2(incl)...
#
#                         Syncretisms (person-separated)                Persons  \
# 603  agalkiŋin; agalkin, (1+3pl(excl), 1+3(excl), R...        1+2+3, 1+2, 1+3
# 228  tuman, (1+3pl(excl), 1+3(excl), Restricted I (...        1+2+3, 1+2, 1+3
# 619  (g)urbanbani-; (ŋ)urbanbani-, (2pl, 2 Restrict...  1+2+3\n1+2, 1+3\n2\n3
# 617  (ga)bandi-, (3pl, 3 Restricted I (dual/min)\n(...  1+2+3, 1+2, 1+3\n2\n3
# 386            an(i)-, (3pl, 3 Restricted I (dual/min)                      3
# 387            un(i)-, (3pl, 3 Restricted I (dual/min)                      3
# 438  ŋidaŋi, (1+3pl(excl), 1+3(excl), Restricted I ...               1+2, 1+3
# 182  ŋidi, (1+3pl(excl), 1+3(excl), Restricted I (d...               1+2, 1+3
# 335                ɪl, (3sg, 3 Restricted I (dual/min)                      3
# 366    lagɪaw (anim.), (3sg, 3 Restricted I (dual/min)                      3
# 188  itam, (1+3pl(excl), 1+3(excl), Restricted I (d...     1+2+3, 1+2, 1+3\n2
# 85             ni˨pu˦, (3sg, 3 Restricted I (dual/min)                      3
# 41   kəl; kale, (2pl, 2 Restricted I (dual/min)\nkə...                   2\n3
# 557  -ma, (1+3pl(excl), 1+3(excl), Restricted I (du...  1+2+3, 1+2\n1+3\n3, 2
# 272  -é-a, (2pl, 2 Restricted I (dual/min)\n-í-a, (...                   2\n3
# 616  wujanba-, (3pl, 3 Restricted I (dual/min)\nɭaw...                   2\n3
# 618  wujanba-, (3pl, 3 Restricted I (dual/min)\nɭaw...                   2\n3
# 622  ɳujan-, (1+3pl(excl), 1+3(excl), Restricted I ...              3, 1+3, 1
# 624  ɳuɾan-, (1+3pl(excl), 1+3(excl), Restricted I ...              3, 1+3, 1
# 354           ɲi, (3sg, 3pl, 3 Restricted I (dual/min)                   3, 1
# 416                                               <NA>             1+2+3, 1+2
# 521                                               <NA>             1+2+3, 1+2
# 295                                               <NA>               1+2, 1+3
# 549          -ɓo, (3sg, 3pl, 3 Restricted I (dual/min)                      3
# 139  mahi, (1+3pl(excl), 1+3(excl), Restricted I (d...                    1+3
# 493  wɛnaʝɐk, (2pl, 2 Restricted I (dual/min)\nʔɐwe...                   2\n3
# 383  -nʌŋgori; -dʌgori, (3pl, 3 Restricted II (tria...                      3
# 584                                               <NA>             1+2+3, 1+2
# 120                                               <NA>             1+2+3, 1+2
# 207  hon, (1+3pl(excl), 1+3(excl), Restricted I (du...     1+2+3, 1+2, 1+3\n2
# 310  hoʔnaʔ, (1+3pl(excl), 1+3(excl), Restricted I ...     1+2+3, 1+2, 1+3\n2
#
#                                      Numbers                        Type
# 603                                 pl, dual                       group
# 228                                 pl, dual                       group
# 619  pl, trial\npl, dual\npl, dual\npl, dual  group\ngroup\ngroup\ngroup
# 617      pl, dual, trial\npl, dual\npl, dual         group\ngroup\ngroup
# 386                                 pl, dual                       group
# 387                                 pl, dual                       group
# 438                                 pl, dual                       group
# 182                                 pl, dual                       group
# 335                                 sg, dual                     minimal
# 366                                 sg, dual                     minimal
# 188                       pl, dual\npl, dual                group\ngroup
# 85                                  sg, dual                     minimal
# 41                        pl, dual\npl, dual                group\ngroup
# 557             pl, dual\npl, dual\npl, dual         group\ngroup\ngroup
# 272                       pl, dual\npl, dual                group\ngroup
# 616                       pl, dual\npl, dual                group\ngroup
# 618                       pl, dual\npl, dual                group\ngroup
# 622                             sg, dual, pl                       other
# 624                             sg, dual, pl                       other
# 354                             sg, dual, pl                       other
# 416                                 pl, dual                       group
# 521                                 pl, dual                       group
# 295                                 pl, dual                       group
# 549                             sg, dual, pl                       other
# 139                                 pl, dual                       group
# 493                       pl, dual\npl, dual                group\ngroup
# 383                                pl, trial                       group
# 584                                 pl, dual                       group
# 120                                 pl, dual                       group
# 207                       pl, dual\npl, dual                group\ngroup
# 310                       pl, dual\npl, dual                group\ngroup
